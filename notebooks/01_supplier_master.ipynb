# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import random
import os

np.random.seed(42)
random.seed(42)

print("Ready.")
# Out:
# Ready.

# %% [markdown]
# #### Define options with weights

# %%
REGIONS         = ["NA-West", "NA-East", "NA-Central", "EMEA-Europe", "APAC-China"]
REGION_WEIGHTS  = [0.28, 0.22, 0.18, 0.20, 0.12]

TIERS           = ["Tier 1", "Tier 2", "Tier 3"]
TIER_WEIGHTS    = [0.50, 0.35, 0.15]

PART_CATEGORIES = ["Battery Systems", "Powertrain", "Electronics",
                   "Interior", "Chassis & Frame", "Thermal Management",
                   "Fasteners", "Exterior Panels"]

RISK_PROFILES   = ["Low", "Medium", "High"]
RISK_WEIGHTS    = [0.40, 0.40, 0.20]

PLANTS = {
    "NA-West":    "Giga Fremont",
    "NA-East":    "Giga New York",
    "NA-Central": "Giga Texas",
    "EMEA-Europe":"Giga Berlin",
    "APAC-China": "Giga Shanghai"
}

print("Config ready.")
# Out:
# Config ready.

# %% [markdown]
# #### Build supplier master

# %%
rows = []

for i in range(1, 121):
    region = np.random.choice(REGIONS, p=REGION_WEIGHTS)
    tier   = np.random.choice(TIERS,   p=TIER_WEIGHTS)

    rows.append({
        "supplier_id":        f"SUPP_{str(i).zfill(3)}",
        "supplier_name":      f"Supplier_{str(i).zfill(3)}",
        "region":             region,
        "primary_plant":      PLANTS[region],
        "tier":               tier,
        "part_category":      np.random.choice(PART_CATEGORIES),
        "risk_profile":       np.random.choice(RISK_PROFILES, p=RISK_WEIGHTS),
        "contract_value_usd": random.randint(500_000, 50_000_000),
        "active_parts":       random.randint(5, 180),
    })

df_suppliers = pd.DataFrame(rows)
print(df_suppliers.shape)
print(df_suppliers.head())
# Out:
# (120, 9)
#   supplier_id supplier_name       region  primary_plant    tier  \
# 0    SUPP_001  Supplier_001      NA-East  Giga New York  Tier 3
# 1    SUPP_002  Supplier_002   NA-Central     Giga Texas  Tier 1
# 2    SUPP_003  Supplier_003  EMEA-Europe    Giga Berlin  Tier 2
# 3    SUPP_004  Supplier_004      NA-West   Giga Fremont  Tier 2
# 4    SUPP_005  Supplier_005      NA-West   Giga Fremont  Tier 1
#
#         part_category risk_profile  contract_value_usd  active_parts
# 0         Electronics       Medium            43411206            33
# 1           Fasteners          Low             2178443            75
# 2     Exterior Panels       Medium            16934414            62
# 3  Thermal Management          Low             9864231            31
# 4            Interior       Medium            45912533           144

# %% [markdown]
# #### Sanity check

# %%
print("=== TIER ===")
print(df_suppliers["tier"].value_counts())

print("\n=== REGION ===")
print(df_suppliers["region"].value_counts())

print("\n=== RISK ===")
print(df_suppliers["risk_profile"].value_counts())

print("\n=== NULLS ===")
print(df_suppliers.isnull().sum())
# Out:
# === TIER ===
# tier
# Tier 1    64
# Tier 2    36
# Tier 3    20
# Name: count, dtype: int64
#
# === REGION ===
# region
# NA-West        34
# NA-Central     24
# NA-East        23
# EMEA-Europe    22
# APAC-China     17
# Name: count, dtype: int64
#
# === RISK ===
# risk_profile
# Low       49
# Medium    48
# High      23
# Name: count, dtype: int64
#
# === NULLS ===
# supplier_id           0
# supplier_name         0
# region                0
# primary_plant         0
# tier                  0
# part_category         0
# risk_profile          0
# contract_value_usd    0
# active_parts          0
# dtype: int64

# %% [markdown]
# #### Save

# %%
os.makedirs("../data", exist_ok=True)
df_suppliers.to_csv("../data/supplier_master.csv", index=False)

verify = pd.read_csv("../data/supplier_master.csv")
print(f"Saved: {verify.shape}")
# Out:
# Saved: (120, 9)
